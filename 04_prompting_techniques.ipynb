# %% [markdown]
# <a href="https://colab.research.google.com/github/Moshood6464/Power-BI-and-Excel/blob/main/04_prompting_techniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1.4: Prompt Engineering for Digital Twins
#
# ## Learning Objectives
# - Master different prompting techniques
# - Understand zero-shot, few-shot, and chain-of-thought
# - Apply prompting to digital twin interactions
#
# ## Key Insight
# > 'Moving from Chat to System Instructions'

# %%
import numpy as np
import matplotlib.pyplot as plt
from typing import List, Dict

print('✅ Ready for prompting exercises!')

# %% [markdown]
# ## Part 1: Prompting Fundamentals
#
# ### 1.1 Zero-Shot Prompting

# %%
# Example prompts for digital twin
zero_shot_examples = [
    {
        'task': 'activity_prediction',
        'prompt': 'Predict the next activity: I just finished work, had dinner, and now...',
        'expected': 'leisure/relaxation activity'
    },
    {
        'task': 'preference_extraction',
        'prompt': 'Extract preferences from: I love outdoor activities but hate crowded places',
        'expected': {'likes': ['outdoor', 'quiet'], 'dislikes': ['crowds']}
    }
]

print('Zero-Shot Examples:')
for ex in zero_shot_examples:
    print(f"\nTask: {ex['task']}")
    print(f"Prompt: {ex['prompt']}")
    print(f"Expected: {ex['expected']}")

# %% [markdown]
# ### 🎯 Exercise 1.1 (Easy): Create Your Prompts
#
# **Task**: Design prompts for your digital twin use case.

# %%
my_prompts = [
      {
              "task": "activity_prediction",
                      "prompt": "User state: It's 10 PM, finished studying, phone screen on low brightness. Predict next action:",
                              "expected": "Sleep or relaxed entertainment (e.g., reading/audiobook)"
                                  },
                                      {
                                              "task": "preference_extraction",
                                                      "prompt": "Extract food preferences from: 'I enjoy high-protein meals, love spicy Asian food, but hate dairy.'",
                                                              "expected": {"likes": ["high-protein", "spicy", "Asian"], "dislikes": ["dairy"]}
                                                                  },
                                                                      {
                                                                              "task": "decision_simulation",
                                                                                      "prompt": "Digital Twin Profile: Prefers budget options, highly values fast delivery. Scenario: Choose a delivery service for dinner.",
                                                                                              "expected": "Select fastest delivery with low/moderate service fee"
                                                                                                  }
]
