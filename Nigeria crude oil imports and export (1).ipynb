# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('3MTT CAPSTONE PP/International Energy Agency - Crude oil production, Nigeria.csv')

# %%
df.head(5)
# Out:
#    Year  Crude oil production, Nigeria Units
# 0  2000                        4923513    TJ
# 1  2001                        5160417    TJ
# 2  2002                        4429358    TJ
# 3  2003                        5041538    TJ
# 4  2004                        5449430    TJ

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Recreate the dataset from the image
data = {
    'Year': list(range(2000, 2024)),
    'Crude_Oil_TJ': [
        4923513, 5160417, 4429358, 5041538, 5449430, 5499316, 5228556, 4880595,
        4668570, 4678701, 5407965, 5239072, 5184954, 4693492, 4691141, 4535371,
        3917677, 3979130, 4084111, 4295487, 3307055, 2944359, 2555025, 2737203
    ]
}

df = pd.DataFrame(data)

# %%
# 2. Basic Descriptive Statistics
print("--- Summary Statistics ---")
print(df.describe())
# Out:
# --- Summary Statistics ---
#               Year  Crude_Oil_TJ
# count    24.000000  2.400000e+01
# mean   2011.500000  4.480502e+06
# std       7.071068  8.600914e+05
# min    2000.000000  2.555025e+06
# 25%    2005.750000  4.057866e+06
# 50%    2011.500000  4.684921e+06
# 75%    2017.250000  5.166551e+06
# max    2023.000000  5.499316e+06

# %%
# 3. Feature Engineering: Year-over-Year (YoY) Percentage Change
df['YoY_Growth_%'] = df['Crude_Oil_TJ'].pct_change() * 100

# %%
# Finding key milestones
peak_year = df.loc[df['Crude_Oil_TJ'].idxmax()]
lowest_year = df.loc[df['Crude_Oil_TJ'].idxmin()]

print(f"\nPeak Production Year: {int(peak_year['Year'])} ({peak_year['Crude_Oil_TJ']:,} TJ)")
print(f"Lowest Production Year: {int(lowest_year['Year'])} ({lowest_year['Crude_Oil_TJ']:,} TJ)")
# Out:
# Peak Production Year: 2005 (5,499,316.0 TJ)
# Lowest Production Year: 2022 (2,555,025.0 TJ)

# %%
# 4. Data Visualization
plt.figure(figsize=(14, 6))
