# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Connnect the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Classroom/gender_submission.csv')
print(df.head())
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
#Data cleaning for checking misssing values
print("Missing values per column:\n", df.isnull().sum())
# Out:
# Missing values per column:
#  PassengerId    0
# Survived       0
# dtype: int64

# %%
#Filling the missing Age with the median
# df['Age'] = df['Age'].fillna(df['Age'].median()) # This line caused an error as 'Age' column does not exist in this DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
# dtypes: int64(2)
# memory usage: 6.7 KB

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived'], dtype='object')

# %%
#filling missing embarked with mode
# df['Embarked'].fillna(df['Embarked'].mode()[0]) # This line caused a KeyError as 'Embarked' column does not exist in this DataFrame.

# %%
#Dropping 'Cabin' as it has  too many missing values for basic EDA
# df.drop(columns=['Cabin'],inplace=True) # This line caused a KeyError as 'Cabin' column does not exist in this DataFrame.

# %%
# EDA
print("\nSummary Statistics:\n")
print(df.describe())
# Out:
# Summary Statistics:
#
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.363636
# std     120.810458    0.481622
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %%
# Survival by Gender
# survival_by_gender = df.groupby('Sex')['Survived'].mean() # This line caused an error as 'Sex' column does not exist in this DataFrame.
# print("\nSurvival Rate by Gender :\n", survival_by_gender)

# %%
# Visualization
plt.figure(figsize=(12,5))

# %%
import seaborn as sns
#Plot 1: Survival  by Class
plt.subplot(1,2,1)
# sns.barplot(x='Pclass',y='Survived', data=df, palette='viridis') # This line caused a KeyError as 'Pclass' column does not exist in this DataFrame.
plt.title('Survival Rate By Ticket Class')
# Out:
# Text(0.5, 1.0, 'Survival Rate By Ticket Class')

# %%
#Plot 2: Survival By Gender
plt.subplot(1,2,2)
# sns.barplot(x='Sex', y='Survived',data=df, palette='magma') # This line caused a KeyError as 'Sex' column does not exist in this DataFrame.
plt.title('Survival Rate By Gender')
plt.tight_layout()
plt.show ()

# %%
# Correlation Heatmap
plt.figure(figsize=(10,6))

# %%
import numpy as np
#Only correlate the numeric value
sns.heatmap(df.select_dtypes(include=[np.number]).corr(),annot=True, cmap='coolwarm')
plt.title('Correlatiom Heatmap of Titanic Features')
plt.show()

# %%
display(df)
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
output_path = '/content/drive/MyDrive/gender_submission_saved.csv'
df.to_csv(output_path, index=False)
print(f"DataFrame saved to {output_path}")
# Out:
# DataFrame saved to /content/drive/MyDrive/gender_submission_saved.csv
