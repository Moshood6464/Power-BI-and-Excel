# %%
import pandas as pd
# Load the dataset
df = pd.read_csv('Desktop/3MTT/Superstore csv.csv', encoding= 'latin1')

# %%
df.head(5)
# Out:
#    Row ID  Order ID  Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3  13/10/2010            Low               6    261.5400
# 1      49       293   1/10/2012           High              49  10123.0200
# 2      50       293   1/10/2012           High              27    244.5700
# 3      80       483   10/7/2011           High              30   4965.7595
# 4      85       515   28/8/2010  Not Specified              19    394.2700
#
#    Discount       Ship Mode   Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck   457.81      208.16  ...        Barry French
# 2      0.01     Regular Air    46.71        8.69  ...        Barry French
# 3      0.08     Regular Air  1198.97      195.99  ...       Clay Rozendal
# 4      0.08     Regular Air    30.94       21.78  ...      Carlos Soltero
#
#   Province Region Customer Segment Product Category  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='str')

# %%
#selecting columns
df[[ 'Order ID', 'Customer Name']]
# Out:
#       Order ID       Customer Name
# 0            3  Muhammed MacIntyre
# 1          293        Barry French
# 2          293        Barry French
# 3          483       Clay Rozendal
# 4          515      Carlos Soltero
# ...        ...                 ...
# 8394     55558          Mick Brown
# 8395     55558          Mick Brown
# 8396     56550        Frank Hawley
# 8397     56550        Frank Hawley
# 8398     56581     Grant Donatelli
#
# [8399 rows x 2 columns]

# %%
#Filtering Data (Where)
df[df['Region']=='West']
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 735     8263     59074  12/8/2010            Low              37   589.6300
# 736     8292     59233  20/8/2010           High               3   336.8400
# 737     8293     59233  20/8/2010           High              30   397.1700
# 738     8316     59425  17/5/2012         Medium              24  2094.1200
# 739     8317     59425  17/5/2012         Medium              46  1714.0200
# ...      ...       ...        ...            ...             ...        ...
# 8394    7765     55558   9/8/2010         Medium               8  1294.0400
# 8395    7766     55558   9/8/2010         Medium              23   392.5700
# 8396    7906     56550   8/4/2011  Not Specified              37   823.7800
# 8397    7907     56550   8/4/2011  Not Specified               8   469.8375
# 8398    7914     56581   8/2/2009           High              20  2026.0100
#
# ...

# %%
#Sorting Data ( Order By)
df.sort_values(by='Sales',ascending= False)
# Out:
#       Row ID  Order ID  Order Date Order Priority  Order Quantity     Sales  \
# 4674    4190     29766   21/3/2009         Medium              13  89061.05
# 3512     452      3073    7/1/2009         Medium               7  45923.76
# 5861    4264     30343   21/5/2012       Critical               8  41343.21
# 3572    2026     14435   1/12/2012  Not Specified               9  33367.85
# 6995    4629     32932    9/1/2010            Low              49  29884.60
# ...      ...       ...         ...            ...             ...       ...
# 3343    1314      9635   13/4/2009       Critical               1      3.42
# 7224    6987     49925   22/1/2010           High               1      3.41
# 6495    3263     23361    3/7/2010       Critical               2      3.23
# 7661    3553     25318  19/11/2011       Critical               1      3.20
# 1066     889      6374    7/8/2011       Critical               1      2.24
#
# ...

# %%
# Aggregating data
df.groupby('Ship Mode')['Order Quantity'].sum()
# Out:
# Ship Mode
# Delivery Truck     28764
# Express Air        25353
# Regular Air       160660
# Name: Order Quantity, dtype: int64
