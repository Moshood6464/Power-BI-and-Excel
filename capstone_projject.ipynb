# %%
# step 1: Import libraries
import pandas  as pd
import numpy   as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import glob
print (glob.glob("*.csv"))
# Out:
# []

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Step 2: We read the dataset
df = pd.read_excel('/content/drive/MyDrive/Classroom/cafe_sales.xlsx')

# %%
df.head (10)
# Out:
#   Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0    TXN_1961373    Coffee        2              2           4
# 1    TXN_4977031      Cake        4              3          12
# 2    TXN_4271903    Cookie        4              1       ERROR
# 3    TXN_7034554     Salad        2              5          10
# 4    TXN_3160411    Coffee        2              2           4
# 5    TXN_2602893  Smoothie        5              4          20
# 6    TXN_4433211   UNKNOWN        3              3           9
# 7    TXN_6699534  Sandwich        4              4          16
# 8    TXN_4717867       NaN        5              3          15
# 9    TXN_2064365  Sandwich        5              4          20
#
#    Payment Method  Location     Transaction Date
# 0     Credit Card  Takeaway  2023-08-09 00:00:00
# 1            Cash  In-store            5/16/2023
# 2     Credit Card  In-store            7/19/2023
# 3         UNKNOWN   UNKNOWN            4/27/2023
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
import numpy as np
df.replace(['ERROR','UNKNOWN','unknown'],np.nan,inplace=True)

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 969
# Quantity             479
# Price Per Unit       533
# Total Spent          502
# Payment Method      3178
# Location            3961
# Transaction Date    4202
# dtype: int64

# %%
df.head(20)
# Out:
#    Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0     TXN_1961373    Coffee       2.0             2.0          4.0
# 1     TXN_4977031      Cake       4.0             3.0         12.0
# 2     TXN_4271903    Cookie       4.0             1.0          NaN
# 3     TXN_7034554     Salad       2.0             5.0         10.0
# 4     TXN_3160411    Coffee       2.0             2.0          4.0
# 5     TXN_2602893  Smoothie       5.0             4.0         20.0
# 6     TXN_4433211       NaN       3.0             3.0          9.0
# 7     TXN_6699534  Sandwich       4.0             4.0         16.0
# 8     TXN_4717867       NaN       5.0             3.0         15.0
# 9     TXN_2064365  Sandwich       5.0             4.0         20.0
# 10    TXN_2548360     Salad       5.0             5.0         25.0
# 11    TXN_3051279  Sandwich       2.0             4.0          8.0
# 12    TXN_7619095  Sandwich       2.0             4.0          8.0
# ...

# %%
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].str.strip()

# %%
df['Quantity']=pd.to_numeric(df['Quantity'],errors='coerce')
df['Price Per Unit']=pd.to_numeric(df['Price Per Unit'],errors='coerce')
pd.to_numeric(df['Price Per Unit'],errors='coerce')
# Out:
# 0       2.0
# 1       3.0
# 2       1.0
# 3       5.0
# 4       2.0
#        ...
# 9995    2.0
# 9996    NaN
# 9997    2.0
# 9998    NaN
# 9999    4.0
# Name: Price Per Unit, Length: 10000, dtype: float64

# %%
df['total spent']=df['Quantity']*df['Price Per Unit']

# %%
df['Transanction Date'] = pd.to_datetime(df['Transaction Date'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9031 non-null   object
#  2   Quantity          9521 non-null   float64
#  3   Price Per Unit    9467 non-null   float64
#  4   Total Spent       9498 non-null   float64
#  5   Payment Method    6822 non-null   object
#  6   Location          6039 non-null   object
#  7   Transaction Date  5798 non-null   object
#  8   total spent       9006 non-null   float64
# dtypes: float64(4), object(5)
# memory usage: 703.3+ KB

# %%
df.head(20)
# Out:
#    Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0     TXN_1961373    Coffee       2.0             2.0          4.0
# 1     TXN_4977031      Cake       4.0             3.0         12.0
# 2     TXN_4271903    Cookie       4.0             1.0          NaN
# 3     TXN_7034554     Salad       2.0             5.0         10.0
# 4     TXN_3160411    Coffee       2.0             2.0          4.0
# 5     TXN_2602893  Smoothie       5.0             4.0         20.0
# 6     TXN_4433211       NaN       3.0             3.0          9.0
# 7     TXN_6699534  Sandwich       4.0             4.0         16.0
# 8     TXN_4717867       NaN       5.0             3.0         15.0
# 9     TXN_2064365  Sandwich       5.0             4.0         20.0
# 10    TXN_2548360     Salad       5.0             5.0         25.0
# 11    TXN_3051279  Sandwich       2.0             4.0          8.0
# 12    TXN_7619095  Sandwich       2.0             4.0          8.0
# ...

# %%
df.to_csv('cleaned_cafe_sales.csv',index=False)
